# %% [markdown]
# <h1>目录<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#打开文件" data-toc-modified-id="打开文件-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>打开文件</a></span></li><li><span><a href="#文件操作步骤" data-toc-modified-id="文件操作步骤-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>文件操作步骤</a></span></li><li><span><a href="#读文件" data-toc-modified-id="读文件-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>读文件</a></span><ul class="toc-item"><li><span><a href="#文件指针" data-toc-modified-id="文件指针-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>文件指针</a></span></li><li><span><a href="#移动指针seed方法" data-toc-modified-id="移动指针seed方法-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>移动指针seed方法</a></span></li><li><span><a href="#指针向后读取一行(readline)" data-toc-modified-id="指针向后读取一行(readline)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>指针向后读取一行(readline)</a></span></li><li><span><a href="#读数据（readlines）" data-toc-modified-id="读数据（readlines）-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>读数据（readlines）</a></span></li><li><span><a href="#如担心忘记关闭文件,-也可是使用自动关闭文件的写法" data-toc-modified-id="如担心忘记关闭文件,-也可是使用自动关闭文件的写法-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>如担心忘记关闭文件, 也可是使用自动关闭文件的写法</a></span></li></ul></li><li><span><a href="#写文件w" data-toc-modified-id="写文件w-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>写文件w</a></span><ul class="toc-item"><li><span><a href="#可以多次写入,-最后关闭才会全部写入" data-toc-modified-id="可以多次写入,-最后关闭才会全部写入-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>可以多次写入, 最后关闭才会全部写入</a></span></li><li><span><a href="#将列表内容写入writelines" data-toc-modified-id="将列表内容写入writelines-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>将列表内容写入writelines</a></span></li></ul></li><li><span><a href="#追加模式a" data-toc-modified-id="追加模式a-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>追加模式a</a></span></li><li><span><a href="#小练习:" data-toc-modified-id="小练习:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>小练习:</a></span><ul class="toc-item"><li><span><a href="#使用with语法再做一遍上面的练习题,-感受两者的区别" data-toc-modified-id="使用with语法再做一遍上面的练习题,-感受两者的区别-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>使用with语法再做一遍上面的练习题, 感受两者的区别</a></span></li></ul></li><li><span><a href="#二进制文件的读写" data-toc-modified-id="二进制文件的读写-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>二进制文件的读写</a></span></li><li><span><a href="#文件的重命名、删除" data-toc-modified-id="文件的重命名、删除-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>文件的重命名、删除</a></span><ul class="toc-item"><li><span><a href="#文件重命名" data-toc-modified-id="文件重命名-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>文件重命名</a></span></li><li><span><a href="#删除文件" data-toc-modified-id="删除文件-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>删除文件</a></span></li></ul></li><li><span><a href="#文件夹的相关操作" data-toc-modified-id="文件夹的相关操作-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>文件夹的相关操作</a></span><ul class="toc-item"><li><span><a href="#创建文件夹" data-toc-modified-id="创建文件夹-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>创建文件夹</a></span></li><li><span><a href="#获取当前目录" data-toc-modified-id="获取当前目录-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>获取当前目录</a></span></li><li><span><a href="#获取目录列表" data-toc-modified-id="获取目录列表-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>获取目录列表</a></span></li><li><span><a href="#删除文件夹" data-toc-modified-id="删除文件夹-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>删除文件夹</a></span></li></ul></li><li><span><a href="#应用1：批量修改文件名" data-toc-modified-id="应用1：批量修改文件名-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>应用1：批量修改文件名</a></span></li><li><span><a href="#应用2-:-制作文件的备份" data-toc-modified-id="应用2-:-制作文件的备份-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>应用2 : 制作文件的备份</a></span></li><li><span><a href="#附录:-os方法大全" data-toc-modified-id="附录:-os方法大全-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>附录: os方法大全</a></span></li></ul></div>

# %% [markdown]
# # I/O操作

# %% [markdown]
# ## 打开文件

# %% [markdown]
# 在python，使用open函数，可以打开一个已经存在的文件，或者创建一个新文件
# ```python
# open(文件名，访问模式)
# ```

# %% [markdown]
# | 访问模式 | 说明                                                         |
# | -------- | ------------------------------------------------------------ |
# | r        | 以只读方式打开文件。文件的指针将会放在文件的开头。这是默认模式。 |
# | w        | 打开一个文件只用于写入。如果该文件已存在则将其覆盖。如果该文件不存在，创建新文件。 |
# | a        | 打开一个文件用于追加。如果该文件已存在，文件指针将会放在文件的结尾。也就是说，新的内容将会被写入到已有内容之后。如果该文件不存在，创建新文件进行写入。 |
# | rb       | 以二进制格式打开一个文件用于只读。文件指针将会放在文件的开头。这是默认模式。 |
# | wb       | 以二进制格式打开一个文件只用于写入。如果该文件已存在则将其覆盖。如果该文件不存在，创建新文件。 |
# | ab       | 以二进制格式打开一个文件用于追加。如果该文件已存在，文件指针将会放在文件的结尾。也就是说，新的内容将会被写入到已有内容之后。如果该文件不存在，创建新文件进行写入。 |
# | r+       | 打开一个文件用于读写。文件指针将会放在文件的开头。           |
# | w+       | 打开一个文件用于读写。如果该文件已存在则将其覆盖。如果该文件不存在，创建新文件。 |
# | a+       | 打开一个文件用于读写。如果该文件已存在，文件指针将会放在文件的结尾。文件打开时会是追加模式。如果该文件不存在，创建新文件用于读写。 |
# | rb+      | 以二进制格式打开一个文件用于读写。文件指针将会放在文件的开头。 |
# | wb+      | 以二进制格式打开一个文件用于读写。如果该文件已存在则将其覆盖。如果该文件不存在，创建新文件。 |
# | ab+      | 以二进制格式打开一个文件用于追加。如果该文件已存在，文件指针将会放在文件的结尾。如果该文件不存在，创建新文件用于读写。 |

# %% [markdown]
# ## 文件操作步骤

# %% [markdown]
# 第一步: 打开文件
#
# ```python
# f = open(文件名, 操作模式, encoding=文件编码)
# ```
#
# 第二步: 读写文件
#
# ```python
# f.read()
# f.write()
# ```
#
# 第三步: 关闭文件
#
# ```python
# f.close()
# ```

# %% [markdown]
# ## 读文件

# %% [markdown]
# 使用f.read(num)可以从文件中读取数据，num表示要从文件中读取的数据的长度（单位是字节），如果没有传入num，那么就表示读取文件中所有的数据

# %%
f = open('test.txt', 'r',  encoding='utf-8') # 打开文件

# %%
data = f.read() # 读文件并将读取到的内容保存到data中

# %%
f.close() # 关闭文件

# %%
data
# Out:
# '情感分析或意见挖掘是人们的观点，情绪，评估对诸如产品，服务，组织等实体的态度。该领域的发展和快速起步得益于网络上的社交媒体，例如产品评论，论坛讨论，微博，微信的快速发展，因为这是人类历史上第一次有如此巨大数字量的形式记录。自2000年初以来，情绪分析已经成长为自然语言处理（NLP）中最活跃的研究领域之一。也是在数据挖掘，Web挖掘，文本挖掘和信息检索方面有广泛的研究。事实上，它已经从计算机科学蔓延到管理科学和社会科学，如市场营销，金融，政治学，通讯，医疗科学，甚至是历史，由于其重要的商业性引发整个社会的共同关注。这种扩散是由于意见是事实的中心，几乎所有的人类活动，在相当程度上，很在意别人怎么看。出于这个原因，无论何时我们需要做出决定，我们都会经常寻找别人的意见。这不仅是对企业而言对个人也是如此。\n\n如今，如果一个人想购买消费产品，其不再局限于问一个人的朋友和家人的意见，因为有很多用户评论和对产品讨论在网络上的公共论坛，我们可以在评论中找出我们想知道的问题，可能还会有令人意想不到的收获。对于一个组织，它可能不再需要进行调查，民意调查和重点人群，以收集公众的意见，因为有丰盈。\n\n这样的信息公开。近年来，我们目睹了那些帖子通过社交媒体重塑企业形象，讨论明星生活，左右公众的情绪和情感，其中有深刻地影响我们的社会和政治制度，这样的帖子还动员群众政治的变化。当我们在感叹人言可畏的同时，我们也不得不承认社交网络的快速发展带来的巨大的道德问题。由此情感分析孕育而生，我们可以通过情感分析或者是舆情系统来帮助政府监控群众的情感变化或者是舆论趋势，来避免发生恶性事件或者是虚假事件的发生。\n\n通常来说，情感分析的目的是为了找出说话者/作者在某些话题上或者针对一个文本两极的观点的态度。这个态度或许是他或她的个人判断或是评估，也许是ta当时的情感状态（就是说，作者在做出这个言论时的情绪状态），或是作者有意向的情感交流（就是作者想要读者所体验的情绪）。'

# %%
print(data)
# Out:
# 情感分析或意见挖掘是人们的观点，情绪，评估对诸如产品，服务，组织等实体的态度。该领域的发展和快速起步得益于网络上的社交媒体，例如产品评论，论坛讨论，微博，微信的快速发展，因为这是人类历史上第一次有如此巨大数字量的形式记录。自2000年初以来，情绪分析已经成长为自然语言处理（NLP）中最活跃的研究领域之一。也是在数据挖掘，Web挖掘，文本挖掘和信息检索方面有广泛的研究。事实上，它已经从计算机科学蔓延到管理科学和社会科学，如市场营销，金融，政治学，通讯，医疗科学，甚至是历史，由于其重要的商业性引发整个社会的共同关注。这种扩散是由于意见是事实的中心，几乎所有的人类活动，在相当程度上，很在意别人怎么看。出于这个原因，无论何时我们需要做出决定，我们都会经常寻找别人的意见。这不仅是对企业而言对个人也是如此。
#
# 如今，如果一个人想购买消费产品，其不再局限于问一个人的朋友和家人的意见，因为有很多用户评论和对产品讨论在网络上的公共论坛，我们可以在评论中找出我们想知道的问题，可能还会有令人意想不到的收获。对于一个组织，它可能不再需要进行调查，民意调查和重点人群，以收集公众的意见，因为有丰盈。
#
# 这样的信息公开。近年来，我们目睹了那些帖子通过社交媒体重塑企业形象，讨论明星生活，左右公众的情绪和情感，其中有深刻地影响我们的社会和政治制度，这样的帖子还动员群众政治的变化。当我们在感叹人言可畏的同时，我们也不得不承认社交网络的快速发展带来的巨大的道德问题。由此情感分析孕育而生，我们可以通过情感分析或者是舆情系统来帮助政府监控群众的情感变化或者是舆论趋势，来避免发生恶性事件或者是虚假事件的发生。
#
# 通常来说，情感分析的目的是为了找出说话者/作者在某些话题上或者针对一个文本两极的观点的态度。这个态度或许是他或她的个人判断或是评估，也许是ta当时的情感状态（就是说，作者在做出这个言论时的情绪状态），或是作者有意向的情感交流（就是作者想要读者所体验的情绪）。

# %% [markdown]
# ### 文件指针

# %% [markdown]
# 文件读写中有指针的概念存在, 打开文件时默认指针处于文件内容开头, 当读取文件全部内容后, 指针移动到文件末尾.
#
# 当文件处于指针末尾时, 是无法读取文件中的字符串的. 而这时如果写入字符串, 会写入到当前文件最后.
#
# read方法默认会直接读取文件全部内容, 因为read方法运行一次后, 指针会处于文件末尾, 这时再次运行read, 无法读取内容.
#
# read方法也可以通过参数空值向后读取几个字节.

# %%
f = open('test.txt', 'r',  encoding='utf-8')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = f.read() # 读文件并将读取到的内容保存到data中
data
# Out:
# ''

# %%
f.close()

# %%
f = open('test.txt', 'r',  encoding='utf-8')

# %%
data = f.read(5)
data
# Out:
# '情感分析或'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data2 = f.read(10)
data2
# Out:
# '意见挖掘是人们的观点'

# %% [markdown]
# ### 移动指针seed方法

# %%
f.seek(0) # 移动回文件其实位置
# Out:
# 0

# %%
data3 = f.read(10)
data3
# Out:
# '情感分析或意见挖掘是'

# %%
f.close() # 关闭文件

# %% [markdown]
# ### 指针向后读取一行(readline)

# %% [markdown]
# 如何想要一次读取一段, 可以使用readline, 一般用的比较少

# %%
f = open('test.txt', 'r',  encoding='utf-8')

# %%
data = f.readline()
data
# Out:
# '情感分析或意见挖掘是人们的观点，情绪，评估对诸如产品，服务，组织等实体的态度。该领域的发展和快速起步得益于网络上的社交媒体，例如产品评论，论坛讨论，微博，微信的快速发展，因为这是人类历史上第一次有如此巨大数字量的形式记录。自2000年初以来，情绪分析已经成长为自然语言处理（NLP）中最活跃的研究领域之一。也是在数据挖掘，Web挖掘，文本挖掘和信息检索方面有广泛的研究。事实上，它已经从计算机科学蔓延到管理科学和社会科学，如市场营销，金融，政治学，通讯，医疗科学，甚至是历史，由于其重要的商业性引发整个社会的共同关注。这种扩散是由于意见是事实的中心，几乎所有的人类活动，在相当程度上，很在意别人怎么看。出于这个原因，无论何时我们需要做出决定，我们都会经常寻找别人的意见。这不仅是对企业而言对个人也是如此。\n'

# %%
data = f.readline()
data
# Out:
# '\n'

# %%
data = f.readline()
data
# Out:
# '如今，如果一个人想购买消费产品，其不再局限于问一个人的朋友和家人的意见，因为有很多用户评论和对产品讨论在网络上的公共论坛，我们可以在评论中找出我们想知道的问题，可能还会有令人意想不到的收获。对于一个组织，它可能不再需要进行调查，民意调查和重点人群，以收集公众的意见，因为有丰盈。\n'

# %%
data = f.readline()
data
# Out:
# '\n'

# %%
f.close()

# %% [markdown]
# ### 读数据（readlines）

# %% [markdown]
# 就像read没有参数时一样，readlines可以按照行的方式把整个文件中的内容进行一次性读取，并且返回的是一个列表，其中每一行的数据为一个元素

# %%
f = open("test.txt", "r", encoding='utf-8')

# %%
data = f.readlines()

# %%
f.close()

# %%
data
# Out:
# ['情感分析或意见挖掘是人们的观点，情绪，评估对诸如产品，服务，组织等实体的态度。该领域的发展和快速起步得益于网络上的社交媒体，例如产品评论，论坛讨论，微博，微信的快速发展，因为这是人类历史上第一次有如此巨大数字量的形式记录。自2000年初以来，情绪分析已经成长为自然语言处理（NLP）中最活跃的研究领域之一。也是在数据挖掘，Web挖掘，文本挖掘和信息检索方面有广泛的研究。事实上，它已经从计算机科学蔓延到管理科学和社会科学，如市场营销，金融，政治学，通讯，医疗科学，甚至是历史，由于其重要的商业性引发整个社会的共同关注。这种扩散是由于意见是事实的中心，几乎所有的人类活动，在相当程度上，很在意别人怎么看。出于这个原因，无论何时我们需要做出决定，我们都会经常寻找别人的意见。这不仅是对企业而言对个人也是如此。\n',
#  '\n',
#  '如今，如果一个人想购买消费产品，其不再局限于问一个人的朋友和家人的意见，因为有很多用户评论和对产品讨论在网络上的公共论坛，我们可以在评论中找出我们想知道的问题，可能还会有令人意想不到的收获。对于一个组织，它可能不再需要进行调查，民意调查和重点人群，以收集公众的意见，因为有丰盈。\n',
#  '\n',
#  '这样的信息公开。近年来，我们目睹了那些帖子通过社交媒体重塑企业形象，讨论明星生活，左右公众的情绪和情感，其中有深刻地影响我们的社会和政治制度，这样的帖子还动员群众政治的变化。当我们在感叹人言可畏的同时，我们也不得不承认社交网络的快速发展带来的巨大的道德问题。由此情感分析孕育而生，我们可以通过情感分析或者是舆情系统来帮助政府监控群众的情感变化或者是舆论趋势，来避免发生恶性事件或者是虚假事件的发生。\n',
#  '\n',
#  '通常来说，情感分析的目的是为了找出说话者/作者在某些话题上或者针对一个文本两极的观点的态度。这个态度或许是他或她的个人判断或是评估，也许是ta当时的情感状态（就是说，作者在做出这个言论时的情绪状态），或是作者有意向的情感交流（就是作者想要读者所体验的情绪）。']

# %%
data[0]
# Out:
# '情感分析或意见挖掘是人们的观点，情绪，评估对诸如产品，服务，组织等实体的态度。该领域的发展和快速起步得益于网络上的社交媒体，例如产品评论，论坛讨论，微博，微信的快速发展，因为这是人类历史上第一次有如此巨大数字量的形式记录。自2000年初以来，情绪分析已经成长为自然语言处理（NLP）中最活跃的研究领域之一。也是在数据挖掘，Web挖掘，文本挖掘和信息检索方面有广泛的研究。事实上，它已经从计算机科学蔓延到管理科学和社会科学，如市场营销，金融，政治学，通讯，医疗科学，甚至是历史，由于其重要的商业性引发整个社会的共同关注。这种扩散是由于意见是事实的中心，几乎所有的人类活动，在相当程度上，很在意别人怎么看。出于这个原因，无论何时我们需要做出决定，我们都会经常寻找别人的意见。这不仅是对企业而言对个人也是如此。\n'

# %%
data[1]
# Out:
# '\n'

# %%
data[2]
# Out:
# '如今，如果一个人想购买消费产品，其不再局限于问一个人的朋友和家人的意见，因为有很多用户评论和对产品讨论在网络上的公共论坛，我们可以在评论中找出我们想知道的问题，可能还会有令人意想不到的收获。对于一个组织，它可能不再需要进行调查，民意调查和重点人群，以收集公众的意见，因为有丰盈。\n'

# %%
f.close()

# %% [markdown]
# ### 如担心忘记关闭文件, 也可是使用自动关闭文件的写法

# %% [markdown]
# 使用with语句中打开的文件, 会在整个with代码块运行完成后, 自动关闭.

# %%
with open('test.txt','r',  encoding='utf-8') as f:
    data = f.read()
# 这样打开的文件, 代码运行结束后会自动关闭

# %% [markdown]
# ## 写文件w

# %% [markdown]
# 写文件和读文件是两个相对应的过程, 基本使用方法和read没有太大区别

# %%
# 写文件中, 如果文件不存在, 则会新建文件, 如果文件已经存在, 则会清空原文件
f = open('test_write.txt', 'w', encoding='utf-8')

# %%
# 写入的内容
content = """常见的mode取值组合
1、r或rt    默认模式，文本模式读
2、rb      二进制文件
3、w或wt    文本模式写，打开前文件存储被清空
4、wb    二进制写，文件存储同样被清空 
5、a   追加模式，只能写在文件末尾"""

# %%
f.write(content) # 将字符串写入到文本中
# Out:
# 119

# %%
f.close() # 关闭文件的时候, 内容才会真正被写入

# %% [markdown]
# ### 可以多次写入, 最后关闭才会全部写入

# %%
# 写文件中, 如果文件不存在, 则会新建文件, 如果文件已经存在, 则会清空原文件
f = open('test_write.txt', 'w', encoding='utf-8')

# %%
s1 = """君不见，黄河之水天上来，奔流到海不复回。
君不见，高堂明镜悲白发，朝如青丝暮成雪。"""

# %%
f.write(s1)
# Out:
# 41

# %%
s2 = """人生得意须尽欢，莫使金樽空对月。
天生我材必有用，千金散尽还复来。
烹羊宰牛且为乐，会须一饮三百杯。
岑夫子，丹丘生，将进酒，杯莫停。"""

# %%
f.write(s2)
# Out:
# 67

# %%
s3 = """与君歌一曲，请君为我倾耳听。
钟鼓馔玉不足贵，但愿长醉不复醒。
古来圣贤皆寂寞，惟有饮者留其名。"""

# %%
f.write('\n\n')
# Out:
# 2

# %%
s4 = """陈王昔时宴平乐，斗酒十千恣欢谑。
主人何为言少钱，径须沽取对君酌。
五花马，千金裘，呼儿将出换美酒，与尔同销万古愁。"""

# %%
f.write(s4)
# Out:
# 58

# %%
f.close()

# %% [markdown]
# ### 将列表内容写入writelines

# %%
# 写文件中, 如果文件不存在, 则会新建文件, 如果文件已经存在, 则会清空原文件
f = open('test_write.txt', 'w', encoding='utf-8')

# %%
L = ['abc', 'mno', 'xyz']

# %%
f.writelines(L)

# %%
f.close()

# %% [markdown]
# ## 追加模式a

# %%
# 追加模式中, 如果文件不存在, 则会新建文件, 如果文件已经存在, 则会再原来的内容后清空
# 追加模式中, 默认打开文件指针处于文件结尾
f = open('test_write.txt', 'a', encoding='utf-8')

# %%
s = """将进酒·君不见
【唐】李白
君不见，黄河之水天上来，奔流到海不复回。
君不见，高堂明镜悲白发，朝如青丝暮成雪。
人生得意须尽欢，莫使金樽空对月。
天生我材必有用，千金散尽还复来。
烹羊宰牛且为乐，会须一饮三百杯。
岑夫子，丹丘生，将进酒，杯莫停。
与君歌一曲，请君为我倾耳听。
钟鼓馔玉不足贵，但愿长醉不复醒。
古来圣贤皆寂寞，惟有饮者留其名。
陈王昔时宴平乐，斗酒十千恣欢谑。
主人何为言少钱，径须沽取对君酌。
五花马，千金裘，呼儿将出换美酒，与尔同销万古愁。"""

# %%
f.write(s)
# Out:
# 231

# %%
f.close()

# %% [markdown]
# ## 小练习:
#
# https://baike.baidu.com/item/我有一个梦想/1375?fr=aladdin
#
# 1. 复制中文版文章内容,赋值给变量
# 2. 写入到本地文件中,名称为 我有一个梦想.txt
# 3. 重新打开文件, 在文件后面追加 英文版内容
# 4. 以读取方式打开文件, 把文件内容按换行符进行分割操作

# %% [markdown]
# ### 使用with语法再做一遍上面的练习题, 感受两者的区别

# %% [markdown]
# # 选学部分

# %% [markdown]
# ## 二进制文件的读写

# %% [markdown]
# 默认模式为t(text)文本操作模式, 如果要操作二进制文件(图片, 视频, 音频等), 需要使用二进制模式b(binary)

# %%
# 加上b就是二进制模式, 没有编码
f = open('图片.jpg', 'rb')

# %%
# 依然是用read读取文件内容, 不过二进制内容无法阅读
data = f.read()
data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x00H\x00H\x00\x00\xff\xe1\x10\xb9Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00b\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00j\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x1b\x00\x00\x00r\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\x8d\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xa4\x00\x00\x00\xd0\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Adobe Photoshop CS Windows\x002018:05:01 22:19:19&\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x02\x01\x00\x04\x00\x00\x00\x01\x00\x00\x01.\x02\x
# ...

# %%
f.close()

# %%
# 我们获取到这个文件的字节之后, 可以将其保存到其他位置
f = open('/Users/mac/Desktop/美女.jpg', 'wb')

# %%
f.write(data)
# Out:
# 235608

# %%
f.close()

# %% [markdown]
# ## 文件的重命名、删除

# %% [markdown]
# 有些时候，需要对文件进行重命名、删除等一些操作，python的os模块可以完成这部分功能.

# %% [markdown]
# ### 文件重命名
#
# os模块中的rename()可以完成对文件的重命名操作
#
# rename(需要修改的文件名, 新的文件名)

# %%
import os

# %%
os.rename("test.txt", 'onepaper.txt')

# %% [markdown]
# ### 删除文件

# %% [markdown]
# os模块中的remove()可以完成对文件的删除操作
#
# remove(待删除的文件名)

# %%
import os

os.remove()

# %% [markdown]
# ## 文件夹的相关操作

# %% [markdown]
# ### 创建文件夹

# %%
os.mkdir()

# %% [markdown]
# ### 获取当前目录

# %%
os.getcwd()
# Out:
# '/Users/mac/Library/Mobile Documents/com~apple~CloudDocs/02.pythoncode/01.备课文件夹/01.Python基础/01.上课代码储存/09.20200502 - Python基础课件重制'

# %% [markdown]
# ### 获取目录列表

# %%
os.listdir()
# Out:
# ['05.Python基础_常用内置函数_新版_学生版.ipynb',
#  '09.Python基础_使用Pymysql操作Mysql储存数据 - 20200508 - 腾讯云.ipynb',
#  'test_write.txt',
#  '20200508 - 面向对象编程_编写一个Mysql数据库的增删改查对象-腾讯云.ipynb',
#  '06.Python基础_函数_学生版 - 20200502.ipynb',
#  '20200502 - python基础预习课件.zip',
#  '06.Python基础_函数 - 20200502.ipynb',
#  '图片.jpg',
#  '20200509 - 面向对象编程_编写一个Mysql数据库的增删改查对象_测试高级功能.ipynb',
#  '03.Python基础_控制流语句_顺序结构_判断结构_循环结构_答案版.ipynb',
#  '10.Python基础_面向对象 - 20200502.ipynb',
#  '20200505 - 面向对象编程_编写一个Mysql数据库的增删改查对象.ipynb',
#  '08.python基础_选学_从硬盘中读写文件 - 20200711.ipynb',
#  '07.Python基础_模块_常用模块_学生版 - 20200502.ipynb',
#  '04.Python基础_列表_元组_字典_集合_课件版_新版_学生版.ipynb',
#  '02.Python基础_标准数据类型_数值型_字符串_新版_答案版.ipynb',
#  '09.Python基础_使用Pymysql操作Mysql储存数据 - 20200502.ipynb',
#  '05.Python基础_常用内置函数_答案版.ipynb',
#  '07.Python基础_模块_常用模块 - 20200502.ipynb',
#  '01.Python基础_菜单_快捷键_基本语法_变量_输入输出_新版_学生版.ipynb',
#  'Python基础 - 面向对象练习题 -  模拟英雄联盟写一个游戏人物的类 - 20200502.ipynb',
#  '01.Python基础_菜单_快捷键_基本语法_变量_输入输出_答案.ipynb',
# ...

# %% [markdown]
# ### 删除文件夹

# %%
os.rmdir()

# %% [markdown]
# ## 应用1：批量修改文件名

# %%
# 1. 获取文件列表
# 2. 用for循环, 依次对每一个文件进行 os.rename
os.listdir('测试文件夹')

# %%
# 对每一个文件进行遍历
# 相对所有的txt文件重命名
for file in os.listdir('测试文件夹'):
#     print('测试文件夹/'+file)
    # 重命名, 批量添加一个前缀 [数据文件]_
    os.rename('测试文件夹/'+file , '测试文件夹/'+'[数据文件]_'+file)

# %%
# 对每一个文件进行遍历
# 相对所有的txt文件重命名
for file in os.listdir('测试文件夹'):
    # 先判断这个文件名后四个字符,是不是 .txt 如果是我们才进行替换
    if file[-4:] == '.txt':
    # 重命名, 批量添加一个前缀 [数据文件]_
        os.rename('测试文件夹/'+file , '测试文件夹/'+'[备份文件]_'+file)

# %% [markdown]
# ## 应用2 : 制作文件的备份

# %%
# 思路:
# 1. 先把要备份的文件读入进来
# 2. 再把读进来的内容,写入到你想备份的目标文件夹里面去

# %%
os.listdir('测试文件夹')

# %%
# 新建文件夹
# 判断这个文件夹存不存在
if not os.path.exists('/Users/mac/Desktop/备份文件夹'):
    os.mkdir('/Users/mac/Desktop/备份文件夹')

for file in os.listdir('测试文件夹'):
    # 通过文件名把数据读取到内存中来
    f = open('测试文件夹/'+file , 'rb')
    data = f.read() # 读取出文件内容
    f.close()
    # 把文件写入到另外一个文件夹里面去
    f = open('/Users/mac/Desktop/备份文件夹/'+'又备份_'+file,'wb')
    # 写入刚才的内容
    f.write(data)
    f.close() # 关闭文件

# %%
# 封装成函数
def copy_backup(old_dir,new_dir):
    # 新建文件夹
    # 判断这个文件夹存不存在
    if not os.path.exists(new_dir):
        os.mkdir(new_dir)

    for file in os.listdir(old_dir):
        # 通过文件名把数据读取到内存中来
        f = open(old_dir +'/'+file , 'rb')
        data = f.read() # 读取出文件内容
        f.close()
        # 把文件写入到另外一个文件夹里面去
        f = open(new_dir+'/'+'又备份_'+file,'wb')
        # 写入刚才的内容
        f.write(data)
        f.close() # 关闭文件

# %% [markdown]
# ## 附录: os方法大全
# ```python
# import os
#
# print(os.getcwd())        # 获得当前工作目录
# print(os.chdir("dirname")) # 改变当前脚本的工作路径，相当于shell下的cd
# print(os.curdir)            # 返回当前目录‘.'
# print(os.pardir)            # 获取当前目录的父目录字符串名‘..'
# print(os.makedirs('dirname1/dirname2'))     # 可生成多层递归目录
# print(os.removedirs('dirname1/dirname2'))      # 若目录为空，则删除，并递归到上一级目录，如若也为空，则删除，依此类推
# print(os.mkdir('test4'))         # 生成单级目录；相当于shell中mkdir dirname
# print(os.rmdir('test4'))        # 删除单级空目录，若目录不为空则无法删除，报错；相当于shell中rmdir dirname
# print(os.listdir('/pythonStudy/s12/test'))   # 列出指定目录下的所有文件和子目录，包括隐藏文件，并以列表方式打印
# print(os.remove('log.log'))            # 删除一个指定的文件
# print(os.rename("oldname","newname"))    # 重命名文件/目录)
# print(os.stat('/pythonStudy/s12/test'))     # 获取文件/目录信息
# print(os.pathsep)            # 输出用于分割文件路径的字符串';'
# print(os.name)               # 输出字符串指示当前使用平台。win->'nt'; Linux->'posix'
# print(os.system(command='bash'))   # 运行shell命令，直接显示
# print(os.environ)                  # 获得系统的环境变量
# print(os.path.abspath('/pythonStudy/s12/test'))   # 返回path规范化的绝对路径
# print(os.path.split('/pythonStudy/s12/test'))     # 将path分割成目录和文件名二元组返回
# print(os.path.dirname('/pythonStudy/s12/test'))    # 返回path的目录。其实就是os.path.split(path)的第一个元素
# print(os.path.basename('/pythonStudy/s12/test'))   # 返回path最后的文件名。如果path以／或\结尾，那么就会返回空值。即os.path.split(path)的第二个元素
# print(os.path.exists('test'))                 # 判断path是否存在
# print(os.path.isabs('/pythonStudy/s12/test'))    # 如果path是绝对路径，返回True
# print(os.path.isfile('test'))                   # 如果path是一个存在的文件，返回True。否则返回False
# print(os.path.isdir('/pythonStudy/s12/test'))    # 如果path是一个存在的目录，则返回True。否则返回False
# print(os.path.getatime('/pythonStudy/s12/test'))   # 返回path所指向的文件或者目录的最后存取时间
# print(os.path.getmtime('/pythonStudy/s12/test'))   # 返回path所指向的文件或者目录的最后修改时间
#
# ```
